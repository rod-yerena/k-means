# %% [markdown]
# # Analizando un grupo de datos con K-means

# %% [markdown]
# ### Importando librerías:

# %%
import pandas as pd
from sklearn.cluster import KMeans
print("Librerías descargadas!!")
# Out:
# Librerías descargadas!!

# %% [markdown]
# ### Importando tabla:

# %%
dataset = pd.read_csv('./in/titanic.csv')
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Limpiando la tabla:

# %%
dataset = dataset.drop('Embarked', 'columns')
dataset = dataset.drop('Ticket', 'columns')
dataset = dataset.drop('Cabin', 'columns')
dataset
# Out:
# C:\Users\rodri\AppData\Local\Temp/ipykernel_2220/838869308.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset = dataset.drop('Embarked', 'columns')
# C:\Users\rodri\AppData\Local\Temp/ipykernel_2220/838869308.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset = dataset.drop('Ticket', 'columns')
# C:\Users\rodri\AppData\Local\Temp/ipykernel_2220/838869308.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dataset = dataset.drop('Cabin', 'columns')
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ...

# %% [markdown]
# ### Tirando filas con datos no numericos para la columna "Age":

# %%
dataset = dataset.dropna()
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Transformando valorés de géneros a numéricos, donde 0 es mujer y 1 hombre:

# %%
dataset['Sex'] = (dataset['Sex'] == 'male').astype(int)
dataset
# Out:
# C:\Users\rodri\AppData\Local\Temp/ipykernel_2220/557924336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Sex'] = (dataset['Sex'] == 'male').astype(int)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# ...

# %%
x = dataset.drop(['Name'], axis=1 )
kmeans = KMeans(n_clusters=3, random_state=1).fit(x) #Usar n_clusters para el númer de grupos deseados, random_state se define con cualquier número para asegurar los mismos resultados
print('='*64) #Esta línea es solo para estética de impresión en terminal
print('Total de grupos:', len(kmeans.cluster_centers_))
print('='*64)
dataset['grupo'] = kmeans.predict(x) #Nombre de la nueva columna donde pondremos nuestra predicción de algoritmo
dataset.to_csv('./out/groups.csv', index=False, header=True) #Creación de archivo en carpeta destino

grouped_df = dataset.groupby(['grupo']) 

for key, group in grouped_df:  #Muestra cada grupo
    print(grouped_df.get_group(key), "\n\n", '='*180)  

print('Archivo creado con éxito en la carpeta "out".')
# Out:
# ...
# Total de grupos: 3
# ...
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 291          292         1       1
# 292          293         0       2
# 293          294         0       3
# 294          295         0       3
# 296          297         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...
